# %%
from googletrans import Translator
import numpy as np
import random
import pandas as pd
import time
import gezi
from gezi import tqdm
import sys
sys.path.append('..')
sys.path.append('../../../../utils')
sys.path.append('../../../../third')
from src import util

# %%
root = '../input/feedback-prize-2021'

# %%
df = pd.read_feather(f'{root}/train_en.fea')

# %%
df
# Out:
#          index            id  part  para_id  para_type  start   end  start2  \
# 0            0  423A1CA112E2     4        0          0      0     1       0
# 1            1  423A1CA112E2     4        1          5      1    45       3
# 2            2  423A1CA112E2     4        2          3     45    60      47
# 3            3  423A1CA112E2     4        3          2     60    76      62
# 4            4  423A1CA112E2     4        4          2     76   139      80
# ...        ...           ...   ...      ...        ...    ...   ...     ...
# 175155  175155  4C471936CD75    10       10          2    576   828     582
# 175156  175156  4C471936CD75    10       11          3    828   839     834
# 175157  175157  4C471936CD75    10       12          2    839   903     845
# 175158  175158  4C471936CD75    10       13          0    903   905     911
# 175159  175159  4C471936CD75    10       14          4    905  1055     913
#
#          end2                                               para  \
# 0         3.0                                   Phones [BR] [BR]
# 1        47.0  Modern humans today are always on their phone....
# 2        62.0  They are some really bad consequences when stu...
# 3        80.0  Some certain areas in the United States ban ph...
# 4       145.0  When people have phones, they know about certa...
# ...       ...                                                ...
# 175155  834.0  seeking multiple opinions before making a hard...
# 175156  845.0  it is better to seek multiple opinions instead...
# 175157  911.0  The impact of asking people to help you make a...
# 175158  913.0                                         Of course,
# 175159    NaN  there are many other reasons one might want to...
#
#                                                      text     pid  kfold  \
# 0       Phones [BR] [BR] Modern humans today are alway...       0      0
# 1       Phones [BR] [BR] Modern humans today are alway...       1      0
# 2       Phones [BR] [BR] Modern humans today are alway...       2      0
# 3       Phones [BR] [BR] Modern humans today are alway...       3      0
# 4       Phones [BR] [BR] Modern humans today are alway...       4      0
# ...                                                   ...     ...    ...
# 175155  In ancient times, and also still today in some...  175155      2
# 175156  In ancient times, and also still today in some...  175156      2
# 175157  In ancient times, and also still today in some...  175157      2
# 175158  In ancient times, and also still today in some...  175158      2
# 175159  In ancient times, and also still today in some...  175159      2
#
#         worker
# 0           20
# 1           20
# 2           20
# 3           20
# 4           20
# ...        ...
# 175155      52
# 175156      52
# 175157      52
# 175158      52
# 175159      52
#
# [175160 rows x 14 columns]

# %%
 def swap_random(seq):
   idx = range(len(seq))
   i1, i2 = random.sample(idx, 2)
   seq[i1], seq[i2] = seq[i2], seq[i1]

# %%
para_id_list = []
para_ids = []
id = None
for row in tqdm(df.itertuples(), total=len(df)):
  row = row._asdict()
  if row['id'] != id:
    if para_ids:
      if len(para_ids) > 1:
        # ic(para_ids)
        swap_random(para_ids)
        # ic(para_ids)
      para_id_list.extend(para_ids)
      para_ids = []
    id = row['id']
  para_ids.append(row['para_id'])
if para_ids:
  if len(para_ids) > 1:
    swap_random(para_ids)
  para_id_list.extend(para_ids)
df['para_id'] = para_id_list
df.head(20)
# Out:
#   0%|          | 0/175160 [00:00<?, ?it/s]
#     index            id  part  para_id  para_type  start  end  start2   end2  \
# 0       0  423A1CA112E2     4        0          0      0    1       0    3.0
# 1       1  423A1CA112E2     4        2          5      1   45       3   47.0
# 2       2  423A1CA112E2     4        1          3     45   60      47   62.0
# 3       3  423A1CA112E2     4        3          2     60   76      62   80.0
# 4       4  423A1CA112E2     4        4          2     76  139      80  145.0
# 5       5  423A1CA112E2     4        5          1    139  163     145  169.0
# 6       6  423A1CA112E2     4        6          2    163  211     169  219.0
# 7       7  423A1CA112E2     4        7          2    211  282     219  294.0
# 8       8  423A1CA112E2     4        8          1    282  297     294  309.0
# 9       9  423A1CA112E2     4        9          2    297  355     309  367.0
# 10     10  423A1CA112E2     4       10          4    355  379     367    NaN
# 11     11  A8445CABFECE    13        0          0      0    3       0    5.0
# 12     12  A8445CABFECE    13        1          3      3   15       5   17.0
# 13     13  A8445CABFECE    13        4          1     15   36      17   40.0
# 14     14  A8445CABFECE    13        3          2     36  177      40  185.0
# 15     15  A8445CABFECE    13        2          4    177  212     185    NaN
# 16     16  6B4F7A0165B9     2        0          0      0    5       0    7.0
# 17     17  6B4F7A0165B9     2        2          5      5   92       7   94.0
# 18     18  6B4F7A0165B9     2        1          3     92  105      94  109.0
# 19     19  6B4F7A0165B9     2        3          1    105  125     109  129.0
#
#                                                  para  \
# 0                                    Phones [BR] [BR]
# 1   Modern humans today are always on their phone....
# 2   They are some really bad consequences when stu...
# 3   Some certain areas in the United States ban ph...
# 4   When people have phones, they know about certa...
# 5   Driving is one of the way how to get around. P...
# 6   That's why there's a thing that's called no te...
# 7   Sometimes on the news there is either an accid...
# 8   Phones are fine to use and it's also the best ...
# 9   If you go through a problem and you can't find...
# 10  The news always updated when people do somethi...
# 11                         Phones & Driving [BR] [BR]
# 12  Drivers should not be able to use phones while...
# 13  Drivers who used their phone while operating a...
# 14  According to an article by the Edgar Snyder Fi...
# 15  In conclusion, drivers should not able to work...
# 16       Cell Phone Operation While Driving [BR] [BR]
# 17  The ability to stay connected to people we kno...
# 18  However, this device is taken to areas that it...
# 19  Within a vehicle capable of traveling upwards ...
#
#                                                  text  pid  kfold  worker
# 0   Phones [BR] [BR] Modern humans today are alway...    0      0      20
# 1   Phones [BR] [BR] Modern humans today are alway...    1      0      20
# 2   Phones [BR] [BR] Modern humans today are alway...    2      0      20
# 3   Phones [BR] [BR] Modern humans today are alway...    3      0      20
# 4   Phones [BR] [BR] Modern humans today are alway...    4      0      20
# 5   Phones [BR] [BR] Modern humans today are alway...    5      0      20
# 6   Phones [BR] [BR] Modern humans today are alway...    6      0      20
# 7   Phones [BR] [BR] Modern humans today are alway...    7      0      20
# 8   Phones [BR] [BR] Modern humans today are alway...    8      0      20
# 9   Phones [BR] [BR] Modern humans today are alway...    9      0      20
# 10  Phones [BR] [BR] Modern humans today are alway...   10      0      20
# 11  Phones & Driving [BR] [BR] Drivers should not ...   11      1      66
# 12  Phones & Driving [BR] [BR] Drivers should not ...   12      1      66
# 13  Phones & Driving [BR] [BR] Drivers should not ...   13      1      66
# 14  Phones & Driving [BR] [BR] Drivers should not ...   14      1      66
# 15  Phones & Driving [BR] [BR] Drivers should not ...   15      1      66
# 16  Cell Phone Operation While Driving [BR] [BR] T...   16      0      10
# 17  Cell Phone Operation While Driving [BR] [BR] T...   17      0      10
# 18  Cell Phone Operation While Driving [BR] [BR] T...   18      0      10
# 19  Cell Phone Operation While Driving [BR] [BR] T...   19      0      10

# %%
ids = []
ids2 = []
texts = []
id = None
words = []
for row in tqdm(df.itertuples(), total=len(df)):
  row = row._asdict()
  if row['id'] != id:
    if words:
      ids.append(id)
      ids2.append(len(ids2))
      texts.append(' '.join(words))
    words = []
    id = row['id']
  col = 'para'
  words.extend(str(row[col]).split(' '))
if words:
  ids.append(id)
  ids2.append(len(ids2))
  texts.append(' '.join(words))
d_text = pd.DataFrame({
  'id': ids,
  'id2': ids2,
  'text': texts
})
d_text
# Out:
#   0%|          | 0/175160 [00:00<?, ?it/s]
#                  id    id2                                               text
# 0      423A1CA112E2      0  Phones [BR] [BR] Modern humans today are alway...
# 1      A8445CABFECE      1  Phones & Driving [BR] [BR] Drivers should not ...
# 2      6B4F7A0165B9      2  Cell Phone Operation While Driving [BR] [BR] T...
# 3      E05C7F5C1156      3  People are debating whether if drivers should ...
# 4      50B3435E475B      4  Texting and driving [BR] [BR] Over half of dri...
# ...             ...    ...                                                ...
# 15589  8F4B595CF9E7  15589  Do you ever want more opinions and options whe...
# 15590  6B5809C83978  15590  Has anyone ever gave you advice? Was the advic...
# 15591  408A7D3D2EEC  15591  Imagine seeking advice from multiple people an...
# 15592  AFEC37C2D43F  15592  There has been at least one point in everyone'...
# 15593  4C471936CD75  15593  In ancient times, and also still today in some...
#
# [15594 rows x 3 columns]

# %%
df = pd.merge(df, d_text, on=['id'], how='inner', suffixes=('_ori', ''))

# %%
df = df.sort_values(['id2', 'para_id'])
df.head(20)
# Out:
#     index            id  part  para_id  para_type  start  end  start2   end2  \
# 0       0  423A1CA112E2     4        0          0      0    1       0    3.0
# 2       2  423A1CA112E2     4        1          3     45   60      47   62.0
# 1       1  423A1CA112E2     4        2          5      1   45       3   47.0
# 3       3  423A1CA112E2     4        3          2     60   76      62   80.0
# 4       4  423A1CA112E2     4        4          2     76  139      80  145.0
# 5       5  423A1CA112E2     4        5          1    139  163     145  169.0
# 6       6  423A1CA112E2     4        6          2    163  211     169  219.0
# 7       7  423A1CA112E2     4        7          2    211  282     219  294.0
# 8       8  423A1CA112E2     4        8          1    282  297     294  309.0
# 9       9  423A1CA112E2     4        9          2    297  355     309  367.0
# 10     10  423A1CA112E2     4       10          4    355  379     367    NaN
# 11     11  A8445CABFECE    13        0          0      0    3       0    5.0
# 12     12  A8445CABFECE    13        1          3      3   15       5   17.0
# 15     15  A8445CABFECE    13        2          4    177  212     185    NaN
# 14     14  A8445CABFECE    13        3          2     36  177      40  185.0
# 13     13  A8445CABFECE    13        4          1     15   36      17   40.0
# 16     16  6B4F7A0165B9     2        0          0      0    5       0    7.0
# 18     18  6B4F7A0165B9     2        1          3     92  105      94  109.0
# 17     17  6B4F7A0165B9     2        2          5      5   92       7   94.0
# 19     19  6B4F7A0165B9     2        3          1    105  125     109  129.0
#
#                                                  para  \
# 0                                    Phones [BR] [BR]
# 2   They are some really bad consequences when stu...
# 1   Modern humans today are always on their phone....
# 3   Some certain areas in the United States ban ph...
# 4   When people have phones, they know about certa...
# 5   Driving is one of the way how to get around. P...
# 6   That's why there's a thing that's called no te...
# 7   Sometimes on the news there is either an accid...
# 8   Phones are fine to use and it's also the best ...
# 9   If you go through a problem and you can't find...
# 10  The news always updated when people do somethi...
# 11                         Phones & Driving [BR] [BR]
# 12  Drivers should not be able to use phones while...
# 15  In conclusion, drivers should not able to work...
# 14  According to an article by the Edgar Snyder Fi...
# 13  Drivers who used their phone while operating a...
# 16       Cell Phone Operation While Driving [BR] [BR]
# 18  However, this device is taken to areas that it...
# 17  The ability to stay connected to people we kno...
# 19  Within a vehicle capable of traveling upwards ...
#
#                                              text_ori  pid  kfold  worker  \
# 0   Phones [BR] [BR] Modern humans today are alway...    0      0      20
# 2   Phones [BR] [BR] Modern humans today are alway...    2      0      20
# 1   Phones [BR] [BR] Modern humans today are alway...    1      0      20
# 3   Phones [BR] [BR] Modern humans today are alway...    3      0      20
# 4   Phones [BR] [BR] Modern humans today are alway...    4      0      20
# 5   Phones [BR] [BR] Modern humans today are alway...    5      0      20
# 6   Phones [BR] [BR] Modern humans today are alway...    6      0      20
# 7   Phones [BR] [BR] Modern humans today are alway...    7      0      20
# 8   Phones [BR] [BR] Modern humans today are alway...    8      0      20
# 9   Phones [BR] [BR] Modern humans today are alway...    9      0      20
# 10  Phones [BR] [BR] Modern humans today are alway...   10      0      20
# 11  Phones & Driving [BR] [BR] Drivers should not ...   11      1      66
# 12  Phones & Driving [BR] [BR] Drivers should not ...   12      1      66
# 15  Phones & Driving [BR] [BR] Drivers should not ...   15      1      66
# 14  Phones & Driving [BR] [BR] Drivers should not ...   14      1      66
# 13  Phones & Driving [BR] [BR] Drivers should not ...   13      1      66
# 16  Cell Phone Operation While Driving [BR] [BR] T...   16      0      10
# 18  Cell Phone Operation While Driving [BR] [BR] T...   18      0      10
# 17  Cell Phone Operation While Driving [BR] [BR] T...   17      0      10
# 19  Cell Phone Operation While Driving [BR] [BR] T...   19      0      10
#
#     id2                                               text
# 0     0  Phones [BR] [BR] Modern humans today are alway...
# 2     0  Phones [BR] [BR] Modern humans today are alway...
# 1     0  Phones [BR] [BR] Modern humans today are alway...
# 3     0  Phones [BR] [BR] Modern humans today are alway...
# 4     0  Phones [BR] [BR] Modern humans today are alway...
# 5     0  Phones [BR] [BR] Modern humans today are alway...
# 6     0  Phones [BR] [BR] Modern humans today are alway...
# 7     0  Phones [BR] [BR] Modern humans today are alway...
# 8     0  Phones [BR] [BR] Modern humans today are alway...
# 9     0  Phones [BR] [BR] Modern humans today are alway...
# 10    0  Phones [BR] [BR] Modern humans today are alway...
# 11    1  Phones & Driving [BR] [BR] Drivers should not ...
# 12    1  Phones & Driving [BR] [BR] Drivers should not ...
# 15    1  Phones & Driving [BR] [BR] Drivers should not ...
# 14    1  Phones & Driving [BR] [BR] Drivers should not ...
# 13    1  Phones & Driving [BR] [BR] Drivers should not ...
# 16    2  Cell Phone Operation While Driving [BR] [BR] T...
# 18    2  Cell Phone Operation While Driving [BR] [BR] T...
# 17    2  Cell Phone Operation While Driving [BR] [BR] T...
# 19    2  Cell Phone Operation While Driving [BR] [BR] T...

# %%
df[df.id =='423A1CA112E2']
# Out:
#     index            id  part  para_id  para_type  start  end  start2   end2  \
# 0       0  423A1CA112E2     4        0          0      0    1       0    3.0
# 2       2  423A1CA112E2     4        1          3     45   60      47   62.0
# 1       1  423A1CA112E2     4        2          5      1   45       3   47.0
# 3       3  423A1CA112E2     4        3          2     60   76      62   80.0
# 4       4  423A1CA112E2     4        4          2     76  139      80  145.0
# 5       5  423A1CA112E2     4        5          1    139  163     145  169.0
# 6       6  423A1CA112E2     4        6          2    163  211     169  219.0
# 7       7  423A1CA112E2     4        7          2    211  282     219  294.0
# 8       8  423A1CA112E2     4        8          1    282  297     294  309.0
# 9       9  423A1CA112E2     4        9          2    297  355     309  367.0
# 10     10  423A1CA112E2     4       10          4    355  379     367    NaN
#
#                                                  para  \
# 0                                    Phones [BR] [BR]
# 2   They are some really bad consequences when stu...
# 1   Modern humans today are always on their phone....
# 3   Some certain areas in the United States ban ph...
# 4   When people have phones, they know about certa...
# 5   Driving is one of the way how to get around. P...
# 6   That's why there's a thing that's called no te...
# 7   Sometimes on the news there is either an accid...
# 8   Phones are fine to use and it's also the best ...
# 9   If you go through a problem and you can't find...
# 10  The news always updated when people do somethi...
#
#                                              text_ori  pid  kfold  worker  \
# 0   Phones [BR] [BR] Modern humans today are alway...    0      0      20
# 2   Phones [BR] [BR] Modern humans today are alway...    2      0      20
# 1   Phones [BR] [BR] Modern humans today are alway...    1      0      20
# 3   Phones [BR] [BR] Modern humans today are alway...    3      0      20
# 4   Phones [BR] [BR] Modern humans today are alway...    4      0      20
# 5   Phones [BR] [BR] Modern humans today are alway...    5      0      20
# 6   Phones [BR] [BR] Modern humans today are alway...    6      0      20
# 7   Phones [BR] [BR] Modern humans today are alway...    7      0      20
# 8   Phones [BR] [BR] Modern humans today are alway...    8      0      20
# 9   Phones [BR] [BR] Modern humans today are alway...    9      0      20
# 10  Phones [BR] [BR] Modern humans today are alway...   10      0      20
#
#     id2                                               text
# 0     0  Phones [BR] [BR] Modern humans today are alway...
# 2     0  Phones [BR] [BR] Modern humans today are alway...
# 1     0  Phones [BR] [BR] Modern humans today are alway...
# 3     0  Phones [BR] [BR] Modern humans today are alway...
# 4     0  Phones [BR] [BR] Modern humans today are alway...
# 5     0  Phones [BR] [BR] Modern humans today are alway...
# 6     0  Phones [BR] [BR] Modern humans today are alway...
# 7     0  Phones [BR] [BR] Modern humans today are alway...
# 8     0  Phones [BR] [BR] Modern humans today are alway...
# 9     0  Phones [BR] [BR] Modern humans today are alway...
# 10    0  Phones [BR] [BR] Modern humans today are alway...

# %%
starts, ends = [], []
end = 0
for row in tqdm(df.itertuples(), total=len(df)):
  row = row._asdict()
  if row['para_id'] == 0:
    end = 0
  start = end
  col = 'para' 
  end = start + len(str(row[col]).replace('[BR]', '\n').split())
  starts.append(start)
  ends.append(end)
df['start'] = starts
df['end'] = ends
# Out:
#   0%|          | 0/175160 [00:00<?, ?it/s]

# %%
df
# Out:
#          index            id  part  para_id  para_type  start   end  start2  \
# 0            0  423A1CA112E2     4        0          0      0     1       0
# 2            2  423A1CA112E2     4        1          3      1    16      47
# 1            1  423A1CA112E2     4        2          5     16    60       3
# 3            3  423A1CA112E2     4        3          2     60    76      62
# 4            4  423A1CA112E2     4        4          2     76   139      80
# ...        ...           ...   ...      ...        ...    ...   ...     ...
# 175147  175147  4C471936CD75    10       10          1    809   828     124
# 175156  175156  4C471936CD75    10       11          3    828   839     834
# 175157  175157  4C471936CD75    10       12          2    839   903     845
# 175158  175158  4C471936CD75    10       13          0    903   905     911
# 175159  175159  4C471936CD75    10       14          4    905  1055     913
#
#          end2                                               para  \
# 0         3.0                                   Phones [BR] [BR]
# 2        62.0  They are some really bad consequences when stu...
# 1        47.0  Modern humans today are always on their phone....
# 3        80.0  Some certain areas in the United States ban ph...
# 4       145.0  When people have phones, they know about certa...
# ...       ...                                                ...
# 175147  143.0  seeking multiple opinions can help you feel be...
# 175156  845.0  it is better to seek multiple opinions instead...
# 175157  911.0  The impact of asking people to help you make a...
# 175158  913.0                                         Of course,
# 175159    NaN  there are many other reasons one might want to...
#
#                                                  text_ori     pid  kfold  \
# 0       Phones [BR] [BR] Modern humans today are alway...       0      0
# 2       Phones [BR] [BR] Modern humans today are alway...       2      0
# 1       Phones [BR] [BR] Modern humans today are alway...       1      0
# 3       Phones [BR] [BR] Modern humans today are alway...       3      0
# 4       Phones [BR] [BR] Modern humans today are alway...       4      0
# ...                                                   ...     ...    ...
# 175147  In ancient times, and also still today in some...  175147      2
# 175156  In ancient times, and also still today in some...  175156      2
# 175157  In ancient times, and also still today in some...  175157      2
# 175158  In ancient times, and also still today in some...  175158      2
# 175159  In ancient times, and also still today in some...  175159      2
#
#         worker    id2                                               text
# 0           20      0  Phones [BR] [BR] Modern humans today are alway...
# 2           20      0  Phones [BR] [BR] Modern humans today are alway...
# 1           20      0  Phones [BR] [BR] Modern humans today are alway...
# 3           20      0  Phones [BR] [BR] Modern humans today are alway...
# 4           20      0  Phones [BR] [BR] Modern humans today are alway...
# ...        ...    ...                                                ...
# 175147      52  15593  In ancient times, and also still today in some...
# 175156      52  15593  In ancient times, and also still today in some...
# 175157      52  15593  In ancient times, and also still today in some...
# 175158      52  15593  In ancient times, and also still today in some...
# 175159      52  15593  In ancient times, and also still today in some...
#
# [175160 rows x 16 columns]

# %%
df[['id', 'para_type', 'start', 'end', 'text', 'kfold', 'worker']].reset_index().to_feather(f'{root}/train_swap.fea')

# %%
df[df.id =='423A1CA112E2']
# Out:
#     index            id  part  para_id  para_type  start  end  start2   end2  \
# 0       0  423A1CA112E2     4        0          0      0    1       0    3.0
# 2       2  423A1CA112E2     4        1          3      1   16      47   62.0
# 1       1  423A1CA112E2     4        2          5     16   60       3   47.0
# 3       3  423A1CA112E2     4        3          2     60   76      62   80.0
# 4       4  423A1CA112E2     4        4          2     76  139      80  145.0
# 5       5  423A1CA112E2     4        5          1    139  163     145  169.0
# 6       6  423A1CA112E2     4        6          2    163  211     169  219.0
# 7       7  423A1CA112E2     4        7          2    211  282     219  294.0
# 8       8  423A1CA112E2     4        8          1    282  297     294  309.0
# 9       9  423A1CA112E2     4        9          2    297  355     309  367.0
# 10     10  423A1CA112E2     4       10          4    355  379     367    NaN
#
#                                                  para  \
# 0                                    Phones [BR] [BR]
# 2   They are some really bad consequences when stu...
# 1   Modern humans today are always on their phone....
# 3   Some certain areas in the United States ban ph...
# 4   When people have phones, they know about certa...
# 5   Driving is one of the way how to get around. P...
# 6   That's why there's a thing that's called no te...
# 7   Sometimes on the news there is either an accid...
# 8   Phones are fine to use and it's also the best ...
# 9   If you go through a problem and you can't find...
# 10  The news always updated when people do somethi...
#
#                                              text_ori  pid  kfold  worker  \
# 0   Phones [BR] [BR] Modern humans today are alway...    0      0      20
# 2   Phones [BR] [BR] Modern humans today are alway...    2      0      20
# 1   Phones [BR] [BR] Modern humans today are alway...    1      0      20
# 3   Phones [BR] [BR] Modern humans today are alway...    3      0      20
# 4   Phones [BR] [BR] Modern humans today are alway...    4      0      20
# 5   Phones [BR] [BR] Modern humans today are alway...    5      0      20
# 6   Phones [BR] [BR] Modern humans today are alway...    6      0      20
# 7   Phones [BR] [BR] Modern humans today are alway...    7      0      20
# 8   Phones [BR] [BR] Modern humans today are alway...    8      0      20
# 9   Phones [BR] [BR] Modern humans today are alway...    9      0      20
# 10  Phones [BR] [BR] Modern humans today are alway...   10      0      20
#
#     id2                                               text
# 0     0  Phones [BR] [BR] Modern humans today are alway...
# 2     0  Phones [BR] [BR] Modern humans today are alway...
# 1     0  Phones [BR] [BR] Modern humans today are alway...
# 3     0  Phones [BR] [BR] Modern humans today are alway...
# 4     0  Phones [BR] [BR] Modern humans today are alway...
# 5     0  Phones [BR] [BR] Modern humans today are alway...
# 6     0  Phones [BR] [BR] Modern humans today are alway...
# 7     0  Phones [BR] [BR] Modern humans today are alway...
# 8     0  Phones [BR] [BR] Modern humans today are alway...
# 9     0  Phones [BR] [BR] Modern humans today are alway...
# 10    0  Phones [BR] [BR] Modern humans today are alway...

# %%
df[df.id =='423A1CA112E2'].text.values[0]
# Out:
# "Phones [BR] [BR] Modern humans today are always on their phone. They are always on their phone more than 5 hours a day no stop .All they do is text back and forward and just have group Chats on social media. They even do it while driving. They are some really bad consequences when stuff happens when it comes to a phone. Some certain areas in the United States ban phones from class rooms just because of it. [BR] [BR] When people have phones, they know about certain apps that they have .Apps like Facebook Twitter Instagram and Snapchat. So like if a friend moves away and you want to be in contact you can still be in contact by posting videos or text messages. People always have different ways how to communicate with a phone. Phones have changed due to our generation. [BR] [BR] Driving is one of the way how to get around. People always be on their phones while doing it. Which can cause serious Problems. That's why there's a thing that's called no texting while driving. That's a really important thing to remember. Some people still do it because they think It's stupid. No matter what they do they still have to obey it because that's the only way how did he save. [BR] [BR] Sometimes on the news there is either an accident or a suicide. It might involve someone not looking where they're going or tweet that someone sent. It either injury or death. If a mysterious number says I'm going to kill you and they know where you live but you don't know the person's contact [BR] [BR] ,It makes you puzzled and make you start to freak out. Which can end up really badly. [BR] [BR] Phones are fine to use and it's also the best way to come over help. If you go through a problem and you can't find help you ,always have a phone there with you. Even though phones are used almost every day as long as you're safe it would come into use if you get into trouble. Make sure you do not be like this phone while you're in the middle of driving. The news always updated when people do something stupid around that involves their phones. The safest way is the best way to stay safe."

# %%
df[df.id =='423A1CA112E2'].text_ori.values[0]
# Out:
# "Phones [BR] [BR] Modern humans today are always on their phone. They are always on their phone more than 5 hours a day no stop .All they do is text back and forward and just have group Chats on social media. They even do it while driving. They are some really bad consequences when stuff happens when it comes to a phone. Some certain areas in the United States ban phones from class rooms just because of it. [BR] [BR] When people have phones, they know about certain apps that they have .Apps like Facebook Twitter Instagram and Snapchat. So like if a friend moves away and you want to be in contact you can still be in contact by posting videos or text messages. People always have different ways how to communicate with a phone. Phones have changed due to our generation. [BR] [BR] Driving is one of the way how to get around. People always be on their phones while doing it. Which can cause serious Problems. That's why there's a thing that's called no texting while driving. That's a really important thing to remember. Some people still do it because they think It's stupid. No matter what they do they still have to obey it because that's the only way how did he save. [BR] [BR] Sometimes on the news there is either an accident or a suicide. It might involve someone not looking where they're going or tweet that someone sent. It either injury or death. If a mysterious number says I'm going to kill you and they know where you live but you don't know the person's contact [BR] [BR] ,It makes you puzzled and make you start to freak out. Which can end up really badly. [BR] [BR] Phones are fine to use and it's also the best way to come over help. If you go through a problem and you can't find help you ,always have a phone there with you. Even though phones are used almost every day as long as you're safe it would come into use if you get into trouble. Make sure you do not be like this phone while you're in the middle of driving. The news always updated when people do something stupid around that involves their phones. The safest way is the best way to stay safe."
